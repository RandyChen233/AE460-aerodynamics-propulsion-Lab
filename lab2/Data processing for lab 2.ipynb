# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sympy as sym

# %% [markdown]
# ## Task1

# %%
df = pd.read_csv('lab2_pressure.csv')

# %%
len(df.columns)
# Out:
# 21

# %%
df.columns = [['Pressure_loc1','Pressure_loc2','Pressure_loc3','Pressure_loc4','Pressure_loc5','Pressure_loc6',\
               'Pressure_loc7','Pressure_loc8','Pressure_loc9','Pressure_loc10','Pressure_loc11','Pressure_loc12','Pressure_loc13',
              'Pressure_loc14']]

# %%
df.reset_index()
# Out:
#     index  -0.00847  -0.0153839  -0.0170538  -0.021648  -0.0255758  \
# 0       0 -0.010099   -0.019753   -0.020918  -0.024233   -0.029279
# 1       1 -0.007954   -0.016658   -0.026152  -0.028253   -0.033457
# 2       2 -0.003698   -0.010572   -0.033883  -0.036703   -0.041078
# 3       3 -0.004067   -0.012379   -0.024639  -0.043604   -0.046911
# 4       4 -0.004174   -0.014042   -0.024035  -0.039133   -0.055489
# 5       5 -0.004482   -0.015965   -0.028783  -0.040965   -0.051138
# 6       6 -0.003574   -0.015344   -0.029008  -0.043231   -0.053827
# 7       7 -0.003532   -0.015626   -0.029746  -0.045620   -0.059361
# 8       8 -0.003381   -0.014888   -0.027437  -0.043439   -0.059337
# 9       9 -0.007600   -0.020562   -0.028000  -0.039325   -0.053285
# 10     10 -0.012571   -0.028016   -0.030555  -0.034207   -0.043896
# 11     11 -0.027583   -0.052893   -0.051740  -0.051472   -0.050396
# 12     12 -0.032002   -0.054837   -0.054210  -0.052849   -0.050865
# ...
