# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Hydrogen

# %%
hydrogen=pd.read_excel('lab5_data.xlsx', sheet_name='hydrogen')
hydrogen_back=pd.read_excel('lab5_data.xlsx', sheet_name='background_hydrogen')
hydrogen['emission']=hydrogen['Unnamed: 1']-hydrogen_back['Unnamed: 1']

# %%
plt.plot(hydrogen['FLMT04185_1:101'], hydrogen['emission'])
plt.title('Hydrogen Emission Spectra')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Counts')
plt.ylim([0, 60000])
plt.savefig('Hydrogen_Emission.png')

# %% [markdown]
# Helium

# %%
helium=pd.read_excel('lab5_data.xlsx', sheet_name='helium')
helium_back=pd.read_excel('lab5_data.xlsx', sheet_name='helium_background')
helium['emission']=helium['Unnamed: 1']-helium_back['Unnamed: 1']

# %%
plt.plot(helium['FLMT04185_1:101'], helium['emission'])
plt.title('Helium Emission Spectra')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Counts')
plt.ylim([0, 60000])
plt.savefig('Helium_Emission.png')

# %% [markdown]
# Nitrogen

# %%
nitrogen=pd.read_excel('lab5_data.xlsx', sheet_name='nitrogen')
nitrogen_back=pd.read_excel('lab5_data.xlsx', sheet_name='nitrogen_background')
nitrogen['emission']=nitrogen['Unnamed: 1']-nitrogen_back['Unnamed: 1']

# %%
plt.plot(nitrogen['FLMT04185_1:101'], nitrogen['emission'])
plt.title('Nitrogen Emission Spectra')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Counts')
plt.ylim([0, 60000])
plt.savefig('Nitrogen_Emission.png')

# %% [markdown]
# Unknown 1

# %%
unknown1=pd.read_excel('lab5_data.xlsx', sheet_name='unknown1')
unknown1_back=pd.read_excel('lab5_data.xlsx', sheet_name='unknown1_background')
unknown1['emission']=unknown1['Unnamed: 1']-unknown1_back['Unnamed: 1']

# %%
plt.plot(unknown1['FLMT04185_1:101'], unknown1['emission'])
plt.title('Unknown 1 Emission Spectra')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Counts')
plt.ylim([0, 60000])
plt.savefig('Unknown1_Emission.png')

# %% [markdown]
# Unknown 2

# %%
unknown2=pd.read_excel('lab5_data.xlsx', sheet_name='unknown2')
unknown2_back=pd.read_excel('lab5_data.xlsx', sheet_name='unknown2_background')
unknown2['emission']=unknown2['Unnamed: 1']-unknown2_back['Unnamed: 1']

# %%
plt.plot(unknown2['FLMT04185_1:101'], unknown2['emission'])
plt.title('Unknown 2 Emission Spectra')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Counts')
plt.ylim([0, 60000])
plt.savefig('Unknown2_Emission.png')

# %% [markdown]
# Incandescent Bulb

# %%
incandescent=pd.read_excel('lab5_data.xlsx', sheet_name='incandescent light')
incandescent_back=pd.read_excel('lab5_data.xlsx', sheet_name='incandescent light_background')
incandescent['emission']=incandescent['Unnamed: 1']-incandescent_back['Unnamed: 1']

# %%
plt.plot(incandescent['FLMT04185_1:101'], incandescent['emission'])
plt.title('Incandescent Lightbulb Emission Spectra')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Counts')
plt.ylim([0, 60000])
plt.savefig('Incandescent_Emission.png')

# %% [markdown]
# CFL

# %%
CFL=pd.read_excel('lab5_data.xlsx', sheet_name='CFL')
CFL_back=pd.read_excel('lab5_data.xlsx', sheet_name='CFL_background')
CFL['emission']=CFL['Unnamed: 1']-CFL_back['Unnamed: 1']

# %%
plt.plot(CFL['FLMT04185_1:101'], CFL['emission'])
plt.title('CFL Lightbulb Emission Spectra')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Counts')
plt.ylim([0, 60000])
plt.savefig('CFL_Emission.png')

# %% [markdown]
# Halogen

# %%
halogen=pd.read_excel('lab5_data.xlsx', sheet_name='halogen')
halogen_back=pd.read_excel('lab5_data.xlsx', sheet_name='halogen_background')
halogen['emission']=halogen['Unnamed: 1']-halogen_back['Unnamed: 1']

# %%
plt.plot(halogen['FLMT04185_1:101'], halogen['emission'])
plt.title('Halogen Lightbulb Emission Spectra')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Counts')
plt.ylim([0, 60000])
plt.savefig('Halogen_Lightbulb_Emission.png')

# %% [markdown]
# Mercury

# %%
mercury=pd.read_excel('lab5_data.xlsx', sheet_name='mercury')
mercury_back=pd.read_excel('lab5_data.xlsx', sheet_name='mercury_background')
mercury['emission']=mercury['Unnamed: 1']-mercury_back['Unnamed: 1']

# %%
plt.plot(mercury['FLMT04185_1:101'], mercury['emission'])
plt.title('Mercury Emission Spectra')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Counts')
plt.ylim([0, 60000])
plt.savefig('Mercury_Emission.png')
